# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy.sparse as sp

from sklearn.model_selection import train_test_split as train_test_split_sklearn
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OrdinalEncoder


from surprise import Dataset
from surprise import KNNBasic, SVD
from surprise import Reader
from surprise.model_selection import cross_validate, split
from surprise.model_selection import train_test_split
from surprise import accuracy
from surprise.model_selection import GridSearchCV

# %%
movies = pd.read_csv('/kaggle/input/movietweetings/movies.dat', delimiter='::', engine='python', header=None, names = ['Movie ID', 'Movie Title', 'Genre'])
users = pd.read_csv('/kaggle/input/movietweetings/users.dat', delimiter='::', engine='python', header=None, names = ['User ID', 'Twitter ID'])
ratings = pd.read_csv('/kaggle/input/movietweetings/ratings.dat', delimiter='::', engine='python', header=None, names = ['User ID', 'Movie ID', 'Rating', 'Rating Timestamp'])
movies.head()
# Out:
#    Movie ID                                        Movie Title  \
# 0         8      Edison Kinetoscopic Record of a Sneeze (1894)
# 1        10                La sortie des usines Lumière (1895)
# 2        12                      The Arrival of a Train (1896)
# 3        25  The Oxford and Cambridge University Boat Race ...
# 4        91                         Le manoir du diable (1896)
#
#                Genre
# 0  Documentary|Short
# 1  Documentary|Short
# 2  Documentary|Short
# 3                NaN
# 4       Short|Horror

# %%
movies.set_index("Movie ID", inplace=True)

# %%
users.head()
# Out:
#    User ID  Twitter ID
# 0        1   139564917
# 1        2    17528189
# 2        3   522540374
# 3        4   475571186
# 4        5   215022153

# %%
ratings.head()
# Out:
#    User ID  Movie ID  Rating  Rating Timestamp
# 0        1    114508       8        1381006850
# 1        2    499549       9        1376753198
# 2        2   1305591       8        1376742507
# 3        2   1428538       1        1371307089
# 4        3     75314       1        1595468524

# %%
ratings.describe()
# Out:
#              User ID      Movie ID         Rating  Rating Timestamp
# count  906831.000000  9.068310e+05  906831.000000      9.068310e+05
# mean    35597.050164  2.239036e+06       7.315742      1.462485e+09
# std     20522.988882  2.122506e+06       1.852979      7.182302e+07
# min         1.000000  8.000000e+00       0.000000      1.362062e+09
# 25%     18147.000000  7.650100e+05       6.000000      1.397069e+09
# 50%     35396.000000  1.723121e+06       8.000000      1.451972e+09
# 75%     53034.000000  2.938956e+06       9.000000      1.518231e+09
# max     70783.000000  1.474090e+07      10.000000      1.623118e+09

# %%
ratings.head()
# Out:
#    User ID  Movie ID  Rating  Rating Timestamp
# 0        1    114508       8        1381006850
# 1        2    499549       9        1376753198
# 2        2   1305591       8        1376742507
# 3        2   1428538       1        1371307089
# 4        3     75314       1        1595468524

# %%
# make dataset
reader = Reader(rating_scale=(0, 10))
data_suprise = Dataset.load_from_df(ratings[[ 'User ID', 'Movie ID', 'Rating']], reader)

# %%
#param_grid = {'n_factors': [30, 50, 100]}

#gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)

#gs.fit(data_suprise)

# best RMSE score
#print(gs.best_score['rmse'])
#print(gs.best_params['rmse'])

# %%
trainset, testset = train_test_split(data_suprise, test_size=0.2)

# will use SVD 
algo_svd = SVD(n_factors=30, n_epochs=20)

algo_svd.fit(trainset)

predictions = algo_svd.test(testset)

accuracy.rmse(predictions)
# Out:
# RMSE: 1.4989
# 1.4988807906496073

# %%
# sample predicitions
for item in ratings.sample(10).values:
    #print(item)
    uid = item[0] 
    iid = item[1]
    pred = algo_svd.predict(uid, iid, verbose=False)
    print("{:7.3} {:4}".format(pred.est, item[2]))
# Out:
#    4.77    4
#    5.01    5
#     3.2    2
#    6.48    3
#    7.81    7
#     7.5   10
#    6.64    7
#    4.89    5
#    7.14    5
#    8.29    8

# %%
def sample_recommendation(model, data, num, user_ids):

    items = data['Movie ID'].unique()

    for user_id in user_ids:
        print()
        print("*" * 60)
        print("  Recomendations for user_id =", user_id)
        print("*" * 60)
        
        print("\n     Already seen:")
        rtg = data[data["User ID"]== user_id]["Rating"].values
        for i, item in enumerate(data[data["User ID"] == user_id]["Movie ID"].values):           
            print("{:50} user rating = {}".format(movies.loc[item, "Movie Title"], rtg[i]))
        
        #known_positives = data['Movie ID'][data.tocsr()[user_id].indices]
        scores = []
        for item in items:
            scores.append(model.predict(user_id, item).est)
        
        #print(items[:10])
        argsort_scores_idx = np.argsort(scores)[-num:]
        
        #print(top_items[:10])
        #print(scores[np.argsort(scores)])
        
        
        print("\n     Recommended:")

        for id in argsort_scores_idx:
            movie_id = items[id]
            print("{:50} predicted rating = {}".format(movies.loc[movie_id, "Movie Title"], scores[id]))
        print()
sample_recommendation(algo_svd, ratings, 10, [529, 999, 4, 15, 22, 99, 150, 222])
# Out:
# ************************************************************
#   Recomendations for user_id = 529
# ************************************************************
#
#      Already seen:
# Alan Partridge: Alpha Papa (2013)                  user rating = 9
# The Wolf of Wall Street (2013)                     user rating = 5
# The Lone Ranger (2013)                             user rating = 8
# The Wolverine (2013)                               user rating = 8
# Pacific Rim (2013)                                 user rating = 1
# Inside Llewyn Davis (2013)                         user rating = 6
# The Monuments Men (2014)                           user rating = 5
# White House Down (2013)                            user rating = 5
#
#      Recommended:
# Man of Steel (2013)                                predicted rating = 8.973886577017216
# Gisaengchung (2019)                                predicted rating = 8.985167757233798
# The Lord of the Rings: The Return of the King (2003) predicted rating = 8.998128238029599
# 1917 (2019)                                        predicted rating = 9.008417967986974
# Forrest Gump (1994)                                predicted rating = 9.152668813668184
# Reservoir Dogs (1992)                              predicted rating = 9.168669346979911
# MSG 2 the Messenger (2015)                         predicted rating = 9.283555426846977
# Be Somebody (2016)                                 predicted rating = 9.286853267020415
# Se7en (1995)                                       predicted rating = 9.362304971886985
# The Usual Suspects (1995)                          predicted rating = 9.453226452333912
#
#
# ************************************************************
#   Recomendations for user_id = 999
# ************************************************************
#
#      Already seen:
# Rendition (2007)                                   user rating = 8
# Bohemian Rhapsody (2018)                           user rating = 5
# Eye in the Sky (2015)                              user rating = 8
# Mission: Impossible - Fallout (2018)               user rating = 8
# Sicario: Day of the Soldado (2018)                 user rating = 8
# Wind River (2017)                                  user rating = 7
# Salinjaui gieokbeob (2017)                         user rating = 5
#
#      Recommended:
# The Sound of Music (1965)                          predicted rating = 8.906124961782835
# Dag II (2016)                                      predicted rating = 8.923984848683236
# One Flew Over the Cuckoo's Nest (1975)             predicted rating = 8.925073970506073
# Se7en (1995)                                       predicted rating = 8.989820003434373
# Judgment at Nuremberg (1961)                       predicted rating = 9.010434732189264
# Kimi no na wa. (2016)                              predicted rating = 9.044377177641065
# Avengers: Age of Ultron Parody (2015)              predicted rating = 9.286621549955086
# MSG 2 the Messenger (2015)                         predicted rating = 9.320764838115581
# Avengers: Endgame (2019)                           predicted rating = 9.399615859127465
# Be Somebody (2016)                                 predicted rating = 9.572444486130056
#
#
# ************************************************************
#   Recomendations for user_id = 4
# ************************************************************
#
#      Already seen:
# Dallas Buyers Club (2013)                          user rating = 8
# American Hustle (2013)                             user rating = 7
# La vie d'Adèle (2013)                              user rating = 8
# Still Life (2013)                                  user rating = 8
# Hungry Hearts (2014)                               user rating = 8
#
#      Recommended:
# The Salt of the Earth (2014)                       predicted rating = 9.298818419764908
# Five Minutes (2017)                                predicted rating = 9.320838146688942
# Braveheart (1995)                                  predicted rating = 9.382118811269274
# The Lord of the Rings: The Return of the King (2003) predicted rating = 9.445171696965506
# The Dark Knight (2008)                             predicted rating = 9.489815572808798
# Forrest Gump (1994)                                predicted rating = 9.549699244573791
# The Shawshank Redemption (1994)                    predicted rating = 9.629403082413093
# Avengers: Age of Ultron Parody (2015)              predicted rating = 9.650892543231933
# MSG 2 the Messenger (2015)                         predicted rating = 9.880398088931361
# Be Somebody (2016)                                 predicted rating = 9.97083833367714
#
#
# ************************************************************
#   Recomendations for user_id = 15
# ************************************************************
#
#      Already seen:
# Almost Famous (2000)                               user rating = 10
#
#      Recommended:
# Dag II (2016)                                      predicted rating = 9.252210695492455
# It's a Wonderful Life (1946)                       predicted rating = 9.261280264822602
# 12 Angry Men (1957)                                predicted rating = 9.27320091786931
# Five Minutes (2017)                                predicted rating = 9.319038757982515
# The Dark Knight (2008)                             predicted rating = 9.323928992889215
# The Lord of the Rings: The Return of the King (2003) predicted rating = 9.390459729407567
# The Shawshank Redemption (1994)                    predicted rating = 9.45170675377312
# Avengers: Age of Ultron Parody (2015)              predicted rating = 9.646474645166016
# MSG 2 the Messenger (2015)                         predicted rating = 9.822128452543824
# Be Somebody (2016)                                 predicted rating = 9.931755137952909
#
#
# ************************************************************
#   Recomendations for user_id = 22
# ************************************************************
#
#      Already seen:
# Captain America: The Winter Soldier (2014)         user rating = 10
# The Amazing Spider-Man 2 (2014)                    user rating = 10
# Dawn of the Planet of the Apes (2014)              user rating = 8
# The Quiet Ones (2014)                              user rating = 10
# Annabelle (2014)                                   user rating = 9
#
#      Recommended:
# Dangal (2016)                                      predicted rating = 10
# Il buono, il brutto, il cattivo (1966)             predicted rating = 10
# Barry Lyndon (1975)                                predicted rating = 10
# The Sound of Music (1965)                          predicted rating = 10
# The Lord of the Rings: The Return of the King (2003) predicted rating = 10
# Witness for the Prosecution (1957)                 predicted rating = 10
# Kimetsu no Yaiba: Mugen Ressha-Hen (2020)          predicted rating = 10
# Gladiator (2000)                                   predicted rating = 10
# Five Minutes (2017)                                predicted rating = 10
# The Green Mile (1999)                              predicted rating = 10
#
#
# ************************************************************
#   Recomendations for user_id = 99
# ************************************************************
#
#      Already seen:
# Shock Waves (1977)                                 user rating = 6
# Alien (1979)                                       user rating = 9
# Aliens (1986)                                      user rating = 7
# Volcano (1997)                                     user rating = 5
# No Country for Old Men (2007)                      user rating = 8
# Ant-Man (2015)                                     user rating = 7
# Samurai purinsesu: Gedô-hime (2009)                user rating = 6
# Abraham Lincoln: Vampire Hunter (2012)             user rating = 6
# Howl (2015)                                        user rating = 7
# The Green Inferno (2013)                           user rating = 7
# As Above, So Below (2014)                          user rating = 3
# Beneath (2013)                                     user rating = 5
# Honeymoon (2014)                                   user rating = 5
#
#      Recommended:
# The Prestige (2006)                                predicted rating = 9.0970300050932
# The Dark Knight (2008)                             predicted rating = 9.160434394060307
# Avengers: Endgame (2019)                           predicted rating = 9.185302441033278
# Schindler's List (1993)                            predicted rating = 9.19028515627371
# Five Minutes (2017)                                predicted rating = 9.214016002933771
# Avengers: Age of Ultron Parody (2015)              predicted rating = 9.327100130521448
# The Shawshank Redemption (1994)                    predicted rating = 9.417810738844343
# MSG 2 the Messenger (2015)                         predicted rating = 9.510351571794612
# Joker (2019)                                       predicted rating = 9.59628726611398
# Be Somebody (2016)                                 predicted rating = 9.690689546088135
#
#
# ************************************************************
#   Recomendations for user_id = 150
# ************************************************************
#
#      Already seen:
# Autómata (2014)                                    user rating = 6
# Star Wars: Episode IX - The Rise of Skywalker (2019) user rating = 8
# Ad Astra (2019)                                    user rating = 6
# Jigsaw (2017)                                      user rating = 6
# Hotel Artemis (2018)                               user rating = 3
# Escape Room (2019)                                 user rating = 7
# Wounds (2019)                                      user rating = 4
# Earthquake Bird (2019)                             user rating = 8
# El hoyo (2019)                                     user rating = 7
# The Two Popes (2019)                               user rating = 8
#
#      Recommended:
# The Wolf of Wall Street (2013)                     predicted rating = 9.184623269536358
# The Godfather (1972)                               predicted rating = 9.245163300547638
# Joker (2019)                                       predicted rating = 9.253039614218977
# The Dark Knight (2008)                             predicted rating = 9.313926704493955
# The Godfather: Part II (1974)                      predicted rating = 9.323742744792932
# Avengers: Endgame (2019)                           predicted rating = 9.326680441998255
# MSG 2 the Messenger (2015)                         predicted rating = 9.414982247552532
# Avengers: Age of Ultron Parody (2015)              predicted rating = 9.447761840317941
# The Shawshank Redemption (1994)                    predicted rating = 9.52118672602224
# Be Somebody (2016)                                 predicted rating = 9.605471146223621
#
#
# ************************************************************
#   Recomendations for user_id = 222
# ************************************************************
#
#      Already seen:
# The Wolf of Wall Street (2013)                     user rating = 8
# Lone Survivor (2013)                               user rating = 8
# Rock of Ages (2012)                                user rating = 6
# The Judge (2014)                                   user rating = 8
# Mud (2012)                                         user rating = 7
# The Counselor (2013)                               user rating = 5
# The Other Woman (2014)                             user rating = 7
# Enemy (2013)                                       user rating = 3
# Kingsman: The Secret Service (2014)                user rating = 7
#
#      Recommended:
# Forrest Gump (1994)                                predicted rating = 9.125611519413896
# The Dark Knight (2008)                             predicted rating = 9.145277728739197
# La vita è bella (1997)                             predicted rating = 9.15541537063951
# Joker (2019)                                       predicted rating = 9.191921183300238
# Inception (2010)                                   predicted rating = 9.25262408046622
# Pulp Fiction (1994)                                predicted rating = 9.305623827353608
# Avengers: Age of Ultron Parody (2015)              predicted rating = 9.364358456504444
# MSG 2 the Messenger (2015)                         predicted rating = 9.508258003172122
# The Shawshank Redemption (1994)                    predicted rating = 9.54494211245947
# Be Somebody (2016)                                 predicted rating = 9.551977701338124
